# %%
import os

### Little hack to reproducibly set working dir as the project directory (one level up) in notebooks
if "original_dir" not in vars():
    original_dir = os.path.abspath("")

os.chdir(original_dir)
os.chdir("..")  ### Adjust as needed to get to root
print(f"Project root (ensure this is correct): {os.getcwd()}")

import src.preprocessing.data_preprocessing as funcs


import geopandas as gpd
import pandas as pd
import numpy as np
import random
import sqlite3
from shapely import wkt
import re
from src.io_utils import io_utils

pd.set_option("display.max_columns", 999)
from app.src.config import BASE_PATH
from shapely import wkb

BASE_PATH_LOCAL = "C:/Users/Francesca Andretta/Downloads/"
db_path = BASE_PATH + "front_end_visualization/F0_raw/digital_twin_database.sqlite"
# Out:
# Project root (ensure this is correct): c:\Users\Francesca Andretta\vegx_thailand_front_end

# %%
BASE_PATH_LOCAL = "C:/Users/Francesca Andretta/Downloads/"
aoj = pd.read_parquet(BASE_PATH_LOCAL + 'aoj.parquet') 
aoj['geometry'] = aoj['geometry'].apply(wkb.loads)
aoj = gpd.GeoDataFrame(aoj)

aoj_old, _ = io_utils.load_file_from_catalog("areas_of_jurisdiction", BASE_PATH)
aoj = gpd.GeoDataFrame(aoj)
aoj_old = gpd.GeoDataFrame(aoj_old)

# %%
aoj[['NAME', 'geometry']].compare(aoj_old[['NAME', 'geometry']])
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
aoj = pd.read_parquet(BASE_PATH + 'aoj.parquet') #io_utils.load_file_from_catalog("areas_of_jurisdiction", BASE_PATH)
corridors_df =  pd.read_parquet(BASE_PATH + 'corridors_df.parquet') #io_utils.load_file_from_catalog("front_end_input", BASE_PATH)

full_corridor_name = corridors_df[
    ["nearest_upstream_device", "full_nearest_upstream_device"]
]

corridors_df = corridors_df.drop("nearest_upstream_device", axis=1).rename(
    columns={"full_nearest_upstream_device": "nearest_upstream_device"}
)

scenario_outcomes = pd.read_parquet(BASE_PATH + 'scenario_outcomes.parquet') #"optimization_scenarios", BASE_PATH)
scenario_outcomes = scenario_outcomes.rename(
    columns={"nearest_upstream_device": "nearest upstream device"}
)
scenario_features = pd.read_parquet(BASE_PATH + 'scenario_features.parquet') #"optimization_metrics", BASE_PATH)
shap_features = pd.read_parquet(BASE_PATH + 'shap_features.parquet') #("model_shap_features", BASE_PATH)
shap_features = shap_features.rename(
    columns={"full_nearest_upstream_device": "nearest upstream device"}
)
values_df = pd.read_parquet(BASE_PATH + 'values_df.parquet')  #("model_inputs_prediction", BASE_PATH)
values_df = values_df.drop("nearest_upstream_device", axis=1).rename(
    columns={"full_nearest_upstream_device": "nearest upstream device"}
)
corridors_df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 aoj = pd.read_parquet(BASE_PATH + 'aoj.parquet') #io_utils.load_file_from_catalog("areas_of_jurisdiction", BASE_PATH)
#       2 corridors_df =  pd.read_parquet(BASE_PATH + 'corridors_df.parquet') #io_utils.load_file_from_catalog("front_end_input", BASE_PATH)
#       4 full_corridor_name = corridors_df[
#       5     ["nearest_upstream_device", "full_nearest_upstream_device"]
#       6 ]
#
# File c:\Users\Francesca Andretta\AppData\Local\miniconda3\envs\thailand_digital_twin_2\Lib\site-packages\pandas\io\parquet.py:667, in read_parquet(path, engine, columns, storage_options, use_nullable_dtypes, dtype_backend, filesystem, filters, **kwargs)
#     664     use_nullable_dtypes = False
#     665 check_dtype_backend(dtype_backend)
# --> 667 return impl.read(
#     668     path,
# ...

# %%
scenario_outcomes
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 scenario_outcomes
#
# NameError: name 'scenario_outcomes' is not defined
